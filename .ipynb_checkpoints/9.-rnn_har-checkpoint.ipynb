# %% [markdown]
# # Reconocimiento de Actividades Humanas
#
# En este laboratorio usaremos registro de actividades capturado por smartphones que fueron desarrolladas por 30 personas distintas. Entre las actividades se incluyen:
#
#     1 WALKING
#     2 WALKING_UPSTAIRS
#     3 WALKING_DOWNSTAIRS
#     4 SITTING
#     5 STANDING
#     6 LAYING
#
# Al mismo tiempo, cada registro de la base de datos incluye las siguientes mediciones:ç
#
# -  Aceleracion total y aceleracion del cuerpo estimada en los 3 ejes (X-Y-Z)
# -  Velocidad angular del giroscopio en 3 los ejes (X-Y-Z)
# -  Un vector de dimensionalidad 561 con descriptores derivados a partir de los datos de movimiento.
# -  Etiqueta de actividad
# -  Un identificador de la persona que ejecuta la actividad
#
# Los datos originales se pueden encontrar en [este enlace](https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones#)
#
# Más información del dataset se encuentra en:
#
# - Davide Anguita, Alessandro Ghio, Luca Oneto, Xavier Parra and Jorge L. Reyes-Ortiz. A Public Domain Dataset for Human Activity Recognition Using Smartphones. 21th European Symposium on Artificial Neural Networks, Computational Intelligence and Machine Learning, ESANN 2013. Bruges, Belgium 24-26 April 2013.

# %%
import numpy as np

X_train=np.load('data/HAR/x_train.npy')
X_test=np.load('data/HAR/x_test.npy')
y_train=np.load('data/HAR/y_train.npy')
y_test=np.load('data/HAR/y_test.npy')

label_to_activity = {1: 'walking horizontally', 2: 'walking upstairs', 3: 'walking downstairs',
                     4: 'sitting', 5: 'standing', 6: 'laying'}

# %%
y_train.shape
# Out:
# (7352, 1)

# %%
np.unique(y_train)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
print(X_train.shape)
# Out:
# (7352, 128, 9)

# %%
import matplotlib.pyplot as plt

def make_plots(num_examples_per_category):
    for label in range(1,7):
        x_label = X_train[y_train[:, 0] == label]
        for i in range(num_examples_per_category):
            fig, ax = plt.subplots(figsize=(10, 1))
            ax.imshow(x_label[100*i].T, cmap='Greys', vmin=-1, vmax=1)
            ax.axis('off')
            if i == 0:
                ax.set_title(label_to_activity[label])
            plt.show()
        
make_plots(2)

# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Flatten,Dense

model = keras.models.Sequential([
    Flatten(input_shape=X_train.shape[1:]),
    Dense(32,activation="relu"),
    Dense(6,activation="softmax")
])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                36896
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 37,094
# Trainable params: 37,094
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train_onehot=to_categorical(y_train-1)
y_test_onehot=to_categorical(y_test-1)

# %%
optimizer = keras.optimizers.SGD(lr=0.01, momentum=0.9, decay=0.001)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
history = model.fit(X_train, y_train_onehot,epochs=100, verbose=1)
score = model.evaluate(X_test, y_test_onehot, verbose=0)
# Out:
# Epoch 1/100
# 230/230 [==============================] - 0s 2ms/step - loss: 1.3725 - accuracy: 0.4974
# Epoch 2/100
# 230/230 [==============================] - 0s 2ms/step - loss: 1.1152 - accuracy: 0.6042
# Epoch 3/100
# 230/230 [==============================] - 0s 2ms/step - loss: 1.0084 - accuracy: 0.6425
# Epoch 4/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.9363 - accuracy: 0.6725
# Epoch 5/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.8782 - accuracy: 0.7002
# Epoch 6/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.8284 - accuracy: 0.7255
# Epoch 7/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.7838 - accuracy: 0.7428
# Epoch 8/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.7438 - accuracy: 0.7620
# Epoch 9/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.7079 - accuracy: 0.7769
# Epoch 10/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.6746 - accuracy: 0.7888
# Epoch 11/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.6442 - accuracy: 0.7995
# Epoch 12/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.6186 - accuracy: 0.8062
# Epoch 13/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.5947 - accuracy: 0.8147
# Epoch 14/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.5729 - accuracy: 0.8195
# Epoch 15/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.5526 - accuracy: 0.8259
# Epoch 16/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.5348 - accuracy: 0.8298
# Epoch 17/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.5174 - accuracy: 0.8376
# Epoch 18/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.5020 - accuracy: 0.8409
# Epoch 19/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.4876 - accuracy: 0.8433
# Epoch 20/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.8483
# Epoch 21/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.8496
# Epoch 22/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.8531
# Epoch 23/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.8584
# Epoch 24/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.4297 - accuracy: 0.8583
# Epoch 25/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.4207 - accuracy: 0.8625
# Epoch 26/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.4116 - accuracy: 0.8643
# Epoch 27/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.4037 - accuracy: 0.8658
# Epoch 28/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8689
# Epoch 29/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3897 - accuracy: 0.8713
# Epoch 30/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3825 - accuracy: 0.8708
# Epoch 31/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3762 - accuracy: 0.8753
# Epoch 32/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.8754
# Epoch 33/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8785
# Epoch 34/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8783
# Epoch 35/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3537 - accuracy: 0.8788
# Epoch 36/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8818
# Epoch 37/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.8834
# Epoch 38/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.3387 - accuracy: 0.8845
# Epoch 39/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8853
# Epoch 40/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3297 - accuracy: 0.8876
# Epoch 41/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3260 - accuracy: 0.8868
# Epoch 42/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.3218 - accuracy: 0.8901
# Epoch 43/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.8924
# Epoch 44/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3133 - accuracy: 0.8924
# Epoch 45/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3098 - accuracy: 0.8965
# Epoch 46/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3060 - accuracy: 0.8942
# Epoch 47/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.8958
# Epoch 48/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2991 - accuracy: 0.8983
# Epoch 49/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2963 - accuracy: 0.8977
# Epoch 50/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2927 - accuracy: 0.8983
# Epoch 51/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2894 - accuracy: 0.9015
# Epoch 52/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2865 - accuracy: 0.8998
# Epoch 53/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.9023
# Epoch 54/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2816 - accuracy: 0.9018
# Epoch 55/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2782 - accuracy: 0.9021
# Epoch 56/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2755 - accuracy: 0.9041
# Epoch 57/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2735 - accuracy: 0.9049
# Epoch 58/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2705 - accuracy: 0.9044
# Epoch 59/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.9048
# Epoch 60/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.9075
# Epoch 61/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.9070
# Epoch 62/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2614 - accuracy: 0.9109
# Epoch 63/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2593 - accuracy: 0.9064
# Epoch 64/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.9082
# Epoch 65/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2546 - accuracy: 0.9094
# Epoch 66/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9108
# Epoch 67/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.9129
# Epoch 68/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2485 - accuracy: 0.9116
# Epoch 69/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.9157
# Epoch 70/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.9132
# Epoch 71/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2430 - accuracy: 0.9154
# Epoch 72/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.9151
# Epoch 73/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2393 - accuracy: 0.9157
# Epoch 74/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 0.9180
# Epoch 75/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2362 - accuracy: 0.9181
# Epoch 76/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9177
# Epoch 77/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2327 - accuracy: 0.9188
# Epoch 78/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9172
# Epoch 79/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9195
# Epoch 80/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2282 - accuracy: 0.9200
# Epoch 81/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9200
# Epoch 82/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2261 - accuracy: 0.9217
# Epoch 83/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2243 - accuracy: 0.9210
# Epoch 84/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2230 - accuracy: 0.9221
# Epoch 85/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9234
# Epoch 86/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.9223
# Epoch 87/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2190 - accuracy: 0.9232
# Epoch 88/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9234
# Epoch 89/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2164 - accuracy: 0.9263
# Epoch 90/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2152 - accuracy: 0.9263
# Epoch 91/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2141 - accuracy: 0.9260
# Epoch 92/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2128 - accuracy: 0.9248
# Epoch 93/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.9264
# Epoch 94/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.9266
# Epoch 95/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2095 - accuracy: 0.9297
# Epoch 96/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9276
# Epoch 97/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2072 - accuracy: 0.9274
# Epoch 98/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2065 - accuracy: 0.9285
# Epoch 99/100
# 230/230 [==============================] - 0s 2ms/step - loss: 0.2052 - accuracy: 0.9291
# Epoch 100/100
# 230/230 [==============================] - 1s 2ms/step - loss: 0.2043 - accuracy: 0.9294

# %%
print('validation loss : {0:0.2f}, validation accuracy : {1:0.2f}'.format(*score))
# Out:
# validation loss : 0.52, validation accuracy : 0.83

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.title('loss')
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.title('accuracy')
# Out:
# Text(0.5, 1.0, 'accuracy')

# %%
from tensorflow.keras.layers import Flatten,Dense,SimpleRNN

rnn_model = keras.models.Sequential([
    SimpleRNN(32, return_sequences=True, input_shape=X_train.shape[1:]),
    SimpleRNN(6,activation="softmax")
])

# %%
rnn_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 128, 32)           1344
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 6)                 234
# =================================================================
# Total params: 1,578
# Trainable params: 1,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn_model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
history = rnn_model.fit(X_train, y_train_onehot,epochs=100, verbose=1)
score = rnn_model.evaluate(X_test, y_test_onehot, verbose=0)
# Out:
# Epoch 1/100
# 230/230 [==============================] - 27s 119ms/step - loss: 1.5546 - accuracy: 0.3496
# Epoch 2/100
# 230/230 [==============================] - 27s 118ms/step - loss: 1.4014 - accuracy: 0.3912
# Epoch 3/100
# 230/230 [==============================] - 28s 120ms/step - loss: 1.3657 - accuracy: 0.4176
# Epoch 4/100
# 230/230 [==============================] - 27s 118ms/step - loss: 1.3306 - accuracy: 0.4343
# Epoch 5/100
# 230/230 [==============================] - 28s 120ms/step - loss: 1.3569 - accuracy: 0.4693
# Epoch 6/100
# 230/230 [==============================] - 27s 117ms/step - loss: 1.4922 - accuracy: 0.4468
# Epoch 7/100
# 230/230 [==============================] - 26s 114ms/step - loss: 1.2289 - accuracy: 0.5465
# Epoch 8/100
# 230/230 [==============================] - 26s 114ms/step - loss: 1.1069 - accuracy: 0.5841
# Epoch 9/100
# 230/230 [==============================] - 26s 115ms/step - loss: 1.1014 - accuracy: 0.5635
# Epoch 10/100
# 230/230 [==============================] - 27s 115ms/step - loss: 0.9679 - accuracy: 0.6223
# Epoch 11/100
# 230/230 [==============================] - 27s 115ms/step - loss: 0.8770 - accuracy: 0.6415
# Epoch 12/100
# 230/230 [==============================] - 27s 118ms/step - loss: 0.8540 - accuracy: 0.6450
# Epoch 13/100
# 230/230 [==============================] - 27s 116ms/step - loss: 1.2056 - accuracy: 0.5151
# Epoch 14/100
# 230/230 [==============================] - 28s 120ms/step - loss: 1.4115 - accuracy: 0.3828
# Epoch 15/100
# 230/230 [==============================] - 28s 122ms/step - loss: 1.2821 - accuracy: 0.4646
# Epoch 16/100
# 230/230 [==============================] - 28s 121ms/step - loss: 1.2344 - accuracy: 0.5205
# Epoch 17/100
# 230/230 [==============================] - 28s 122ms/step - loss: 1.3147 - accuracy: 0.4946
# Epoch 18/100
# 230/230 [==============================] - 28s 122ms/step - loss: 1.1656 - accuracy: 0.5235
# Epoch 19/100
# 230/230 [==============================] - 27s 119ms/step - loss: 1.0929 - accuracy: 0.5804
# Epoch 20/100
# 230/230 [==============================] - 27s 117ms/step - loss: 1.4106 - accuracy: 0.4890
# Epoch 21/100
# 230/230 [==============================] - 27s 118ms/step - loss: 1.3819 - accuracy: 0.3891
# Epoch 22/100
# 230/230 [==============================] - 28s 120ms/step - loss: 1.3318 - accuracy: 0.4419
# Epoch 23/100
# 230/230 [==============================] - 29s 125ms/step - loss: 1.3566 - accuracy: 0.4800
# Epoch 24/100
# 162/230 [====================>.........] - ETA: 9s - loss: 1.3260 - accuracy: 0.4520
